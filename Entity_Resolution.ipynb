# %%
import json
import numpy as np
import pandas as pd

# %%
foursquare_data = pd.read_json(open('train/foursquare_train.json'))
locu_data = pd.read_json(open('train/locu_train.json'))

foursquare = foursquare_data.drop(['country', 'region', 'locality'], axis=1)
locu = locu_data.drop(['country', 'region', 'locality'], axis=1)

def cleanPhone(x):
    if x is None or x is ',':
        return ''
    else:
        return x.replace('(', '').replace(')', '').replace('-', '').replace(' ', '')

def cleanWebsite(x):
    if x is None or x is ',':
        return ''
    else:
        return x.replace('https://', '').replace('http://', '').replace('www.', '')

def cleanName(x):
    if x is None or x is ',':
        return ''
    else:
        x = x.replace('\'s', '').replace('#', '').replace('&', '').replace('-', ' ').replace('/', ' ').replace()
        x = x.lower()
        return x

def cleanAddress(x):
    if x is None or x is ',':
        return ''
    else:
        x = x.replace('\'', '').replace('#', '').replace('&', '').replace('.', '').replace('@', '').\
        replace(',', '').replace('-', ' ').replace('/', ' ')
        x = x.lower()
        x = x.replace('street', 'st').replace('avenue', 'ave').replace('boulevard', 'blvd').\
        replace('place', 'pl').replace('square', 'sq').replace('plaza', 'plz')
        return x

foursquare['phone'] = foursquare['phone'].map(cleanPhone)
foursquare['website'] = foursquare['website'].map(cleanWebsite)
foursquare['name'] = foursquare['name'].map(cleanName)
foursquare['street_address'] = foursquare['street_address'].map(cleanAddress)

locu['phone'] = locu['phone'].map(cleanPhone)
locu['website'] = locu['website'].map(cleanWebsite)
locu['name'] = locu['name'].map(cleanName)
locu['street_address'] = locu['street_address'].map(cleanAddress)

f=open("fs_clean.json","w")
f.write(foursquare.to_json())
f=open("lc_clean.json","w")
f.write(locu.to_json())
# Out:
# 96116

# %%
foursquare['street_address'].value_counts()
# Out:
#                                         109
# moving target!                            3
# 275 church st                             2
# 127 w 28th st                             2
# 870 7th ave                               2
# 55 w 21st st                              2
# 764 10th ave                              2
# 1 penn plz                                2
# 203 e 45th st                             2
# 59 4th ave                                2
# 119 e 60 st                               1
# 416 amsterdam ave                         1
# 233 e 77th st                             1
# 405 e 58th st                             1
# 748 9th ave                               1
# 741 saint nicholas ave                    1
# 100 park ave                              1
# 397 8th ave                               1
# 33rd st                                   1
# 35 clinton st                             1
# 1415 5th ave                              1
# 800 columbus ave                          1
# 400 west 20th st suite 2n                 1
# 215 w 28th st                             1
# 518 e 80th st                             1
# 636 broadway                              1
# 547 9th ave                               1
# 250 west 54th st                          1
# 226 east 49th st                          1
# 35 w 19th st                              1
#                                        ...
# 2 cooper sq                               1
# 25 w 45th st                              1
# e 71st st new york ny                     1
# 347 lexington ave manhattan ny 10016      1
# 25 ave b                                  1
# 45 peck slip                              1
# 26 little west 12th st                    1
# 1275 1st ave                              1
# 527 09 lenox ave                          1
# 1538 2nd ave                              1
# 416 w 13th st                             1
# 10 e 23rd st                              1
# 22 cortlandt st                           1
# 77 pearl st                               1
# 132 e 86th st                             1
# 2741 8th ave new york ny 10039            1
# west 93 and broadway                      1
# 141 west 69th st                          1
# 30 rockefeller plz                        1
# 30 rockefeller plz conc35                 1
# 35 first ave                              1
# 65 w broadway                             1
# 120 e 59th st                             1
# 162 ave b                                 1
# 1240 lexington ave                        1
# 98 7th ave s                              1
# 111 john st                               1
# 101 w 31st st                             1
# 2730 frederick douglass blvd              1
# 239 1st ave                               1
# Name: street_address, Length: 482, dtype: int64

# %%
words = {}
for l in foursquare["street_address"]:
    for k in l.strip().split(" "):
        if k not in words:
            words[k]=0
        words[k]+=1

# words = sorted(words.items(),key=lambda x:x[1])

# %%
words
# Out:
# {'': 117,
#  '(jfk)': 1,
#  '08': 1,
#  '09': 1,
#  '1': 7,
#  '10': 2,
#  '100': 3,
#  '10010': 1,
#  '10011': 1,
#  '10016': 1,
#  '10039': 1,
#  '10065': 1,
#  '101': 2,
#  '1016': 1,
#  '1018': 1,
#  '102': 1,
#  '102nd': 1,
#  '103rd': 1,
#  '104': 1,
#  '1059': 1,
#  '1061': 1,
#  '1070': 1,
#  '108': 2,
#  '109': 2,
#  '10th': 9,
#  '11': 1,
#  '110': 5,
#  '111': 5,
#  '112': 1,
#  '1120': 1,
#  '113': 3,
#  '11430': 1,
#  '116th': 2,
#  '117': 1,
#  '117th': 1,
#  '118': 1,
#  '1187': 1,
#  '118th': 1,
#  '119': 1,
#  '11th': 2,
#  '12': 2,
#  '120': 2,
#  '1219': 1,
#  '123': 1,
#  '1231': 1,
#  '123rd': 1,
#  '1240': 1,
#  '125': 4,
#  '125th': 1,
#  '1260': 1,
#  '127': 3,
#  '1275': 1,
#  '128': 1,
#  '12th': 1,
#  '130': 1,
#  '1301': 1,
#  '131': 1,
#  '132': 1,
#  '1331': 1,
#  '134': 1,
#  '1342': 1,
#  '1343': 1,
#  '135': 1,
#  '1350': 1,
#  '137': 2,
#  '139': 1,
#  '13th': 3,
#  '14': 1,
#  '140': 1,
#  '1405': 1,
#  '1408': 1,
#  '141': 1,
#  '1415': 1,
#  '1429': 1,
#  '1442': 1,
#  '145': 1,
#  '145th': 1,
#  '1478': 1,
#  '148': 2,
#  '1481': 1,
#  '149': 1,
#  '1490': 1,
#  '14th': 5,
#  '15': 4,
#  '150': 1,
#  '1505': 1,
#  '1515': 1,
#  '152': 1,
#  '1526': 1,
#  '1528': 1,
#  '153': 1,
#  '1538': 1,
#  '1550': 1,
#  '158': 2,
#  '1590': 1,
#  '1593': 1,
#  '1596': 1,
#  '15th': 5,
#  '161': 1,
#  '162': 4,
#  '1626': 1,
#  '1633': 1,
#  '1650': 1,
#  '167': 1,
#  '169': 1,
#  '1690': 1,
#  '1694': 1,
#  '16th': 1,
#  '17': 1,
#  '170': 2,
#  '172': 2,
#  '1731': 1,
#  '174': 2,
#  '1740': 1,
#  '1755': 1,
#  '176': 1,
#  '177': 2,
#  '178': 1,
#  '18': 2,
#  '181': 1,
#  '181st': 1,
#  '1827': 1,
#  '1830': 1,
#  '1841': 1,
#  '186': 1,
#  '188': 1,
#  '18th': 3,
#  '190': 1,
#  '191': 1,
#  '196': 1,
#  '199': 2,
#  '1998': 1,
#  '19th': 3,
#  '1st': 20,
#  '2': 2,
#  '20': 2,
#  '200': 3,
#  '201': 2,
#  '2020': 1,
#  '203': 3,
#  '2048': 1,
#  '205': 1,
#  '206th': 1,
#  '209e': 1,
#  '20th': 4,
#  '210': 3,
#  '2115': 1,
#  '212': 2,
#  '213': 2,
#  '2133': 1,
#  '214': 2,
#  '215': 2,
#  '216': 1,
#  '2176': 1,
#  '21st': 3,
#  '22': 3,
#  '220': 1,
#  '2200': 1,
#  '222': 1,
#  '223': 1,
#  '2235': 1,
#  '224': 2,
#  '2258': 2,
#  '226': 2,
#  '228': 1,
#  '229': 1,
#  '22nd': 1,
#  '23': 2,
#  '231': 2,
#  '233': 1,
#  '2345': 1,
#  '235': 5,
#  '239': 1,
#  '23rd': 7,
#  '24': 1,
#  '241': 1,
#  '242': 1,
#  '243': 2,
#  '245': 1,
#  '2479': 1,
#  '248': 3,
#  '249': 1,
#  '25': 3,
#  '250': 3,
#  '2534': 1,
#  '25th': 1,
#  '26': 1,
#  '260': 1,
#  '262': 1,
#  '263': 1,
#  '264': 1,
#  '265': 1,
#  '2657': 1,
#  '2664': 1,
#  '26th': 2,
#  '27': 1,
#  '270': 1,
#  '2726': 1,
#  '2730': 1,
#  '274': 1,
#  '2741': 1,
#  '275': 3,
#  '277': 1,
#  '27th': 1,
#  '280': 1,
#  '286': 1,
#  '2869': 1,
#  '28th': 5,
#  '29': 2,
#  '298': 1,
#  '29th': 2,
#  '2e': 1,
#  '2n': 1,
#  '2nd': 17,
#  '3': 1,
#  '30': 3,
#  '3009': 1,
#  '302': 1,
#  '306': 1,
#  '30th': 2,
#  '311': 1,
#  '312': 1,
#  '315': 1,
#  '317': 1,
#  '318': 1,
#  '319': 1,
#  '31st': 2,
#  '32': 1,
#  '323': 1,
#  '326': 1,
#  '330': 4,
#  '333': 1,
#  '339': 1,
#  '33rd': 2,
#  '34': 3,
#  '341': 1,
#  '342': 1,
#  '346': 1,
#  '347': 1,
#  '348': 1,
#  '34th': 2,
#  '35': 7,
#  '353': 1,
#  '3534': 1,
#  '358': 1,
#  '35th': 1,
#  '36': 1,
#  '3609': 1,
#  '366': 1,
#  '367': 1,
#  '36th': 5,
#  '3750': 1,
#  '37th': 1,
#  '38': 1,
#  '380': 1,
#  '38th': 3,
#  '39': 1,
#  '390': 1,
#  '397': 1,
#  '398': 1,
#  '39th': 5,
#  '3rd': 14,
#  '4': 2,
#  '40': 1,
#  '400': 3,
#  '401': 2,
#  '403': 1,
#  '405': 1,
#  '40th': 2,
#  '416': 2,
#  '41st': 1,
#  '420': 2,
#  '421': 1,
#  '425': 2,
#  '428': 1,
#  '42nd': 1,
#  '43rd': 2,
#  '440': 1,
#  '445': 1,
#  '449': 1,
#  '44th': 2,
#  '45': 2,
#  '455': 1,
#  '456': 1,
#  '45th': 5,
#  '467': 1,
#  '46th': 2,
#  '47': 2,
#  '4767': 1,
#  '47th': 3,
#  '487': 1,
#  '48th': 1,
#  '49': 2,
#  '493': 1,
#  '4973': 1,
#  '499': 1,
#  '49th': 2,
#  '4th': 2,
#  '5': 2,
#  '50': 1,
#  '500': 1,
#  '503': 1,
#  '505': 1,
#  '508': 1,
#  '509': 1,
#  '50th': 1,
#  '51': 2,
#  '518': 1,
#  '51st': 1,
#  '521': 2,
#  '525': 1,
#  '527': 1,
#  '52nd': 1,
#  '53': 1,
#  '535': 1,
#  '536': 1,
#  '53rd': 3,
#  '543': 1,
#  '545': 2,
#  '547': 2,
#  '54th': 2,
#  '55': 4,
#  '554': 1,
#  '55b': 1,
#  '55th': 1,
#  '56': 1,
#  '560': 1,
#  '56th': 2,
#  '57th': 3,
#  '58th': 3,
#  '59': 3,
#  '591': 1,
#  '597': 1,
#  '59th': 2,
#  '5th': 6,
#  '6': 1,
#  '60': 3,
#  '601': 2,
#  '60th': 1,
#  '61': 1,
#  '610': 1,
#  '62': 1,
#  '636': 1,
#  '63rd': 1,
#  '64': 1,
#  '65': 1,
#  '65th': 1,
#  '66th': 1,
#  '67': 2,
#  '67th': 1,
#  '68': 1,
#  '680': 1,
#  '681': 1,
#  '6812': 1,
#  '684': 1,
#  '688': 1,
#  '68th': 3,
#  '69': 2,
#  '694': 1,
#  '69th': 1,
#  '6r': 1,
#  '6th': 3,
#  '70': 1,
#  '701': 1,
#  '71': 1,
#  '71st': 1,
#  '72': 2,
#  '732': 1,
#  '741': 1,
#  '748': 1,
#  '74th': 1,
#  '75': 3,
#  '76': 1,
#  '764': 2,
#  '766': 1,
#  '768': 1,
#  '77': 2,
#  '77th': 2,
#  '78': 1,
#  '78th': 1,
#  '79': 1,
#  '7915': 1,
#  '79th': 1,
#  '7th': 8,
#  '80': 1,
#  '800': 2,
#  '801': 1,
#  '80th': 2,
#  '81st': 1,
#  '835': 1,
#  '85': 2,
#  '854': 1,
#  '85th': 1,
#  '862': 1,
#  '86th': 1,
#  '870': 3,
#  '875': 1,
#  '879': 1,
#  '8th': 7,
#  '9': 2,
#  '90': 1,
#  '913': 1,
#  '918': 1,
#  '929': 1,
#  '93': 1,
#  '93rd': 1,
#  '94': 1,
#  '945': 2,
#  '95': 1,
#  '956': 1,
#  '96th': 1,
#  '974': 1,
#  '97th': 1,
#  '98': 1,
#  '9th': 14,
#  'a': 3,
#  'airport': 2,
#  'aka': 1,
#  'albany': 1,
#  'americas': 4,
#  'amsterdam': 12,
#  'and': 5,
#  'anywhere': 2,
#  'apt': 2,
#  'at': 1,
#  'ave': 158,
#  'b': 2,
#  'bay': 1,
#  'bayard': 1,
#  'bedford': 4,
#  'between': 2,
#  'bleecker': 6,
#  'blvd': 7,
#  'bowery': 1,
#  'broadway': 33,
#  'building': 1,
#  'c': 1,
#  'canal': 1,
#  'carmine': 1,
#  'catherine': 1,
#  'cedar': 1,
#  'center': 2,
#  'central': 2,
#  'centre': 2,
#  'charlton': 1,
#  'chelsea': 1,
#  'chez': 1,
#  'church': 3,
#  'ckarkson': 1,
#  'clinton': 1,
#  'columbus': 4,
#  'conc35': 1,
#  'cooper': 1,
#  'corner': 1,
#  'cortlandt': 1,
#  'crosby': 1,
#  'delta': 1,
#  'diana': 1,
#  'district': 1,
#  'douglass': 3,
#  'doyers': 1,
#  'dyckman': 2,
#  'e': 54,
#  'east': 10,
#  'eats': 1,
#  'elizabeth': 1,
#  'end': 1,
#  'essex': 2,
#  'exchange': 2,
#  'f': 1,
#  'first': 3,
#  'fl': 3,
#  'floor': 3,
#  'francis': 1,
#  'franklin': 2,
#  'frederick': 3,
#  'front': 2,
#  'fulton': 2,
#  'gansevoort': 1,
#  'grand': 6,
#  'greene': 1,
#  'greenwich': 2,
#  'hanover': 1,
#  'henry': 1,
#  'hester': 1,
#  'houston': 2,
#  'hudson': 4,
#  'international': 2,
#  'irving': 1,
#  'jamaica': 1,
#  'jfk': 1,
#  'john': 2,
#  'kennedy': 1,
#  'lafayette': 1,
#  'lenox': 1,
#  'lewis': 1,
#  'lexington': 14,
#  'lincoln': 1,
#  'linden': 1,
#  'little': 1,
#  'ln': 1,
#  'ludlow': 2,
#  'macdougal': 1,
#  'mad': 1,
#  'madison': 6,
#  'maiden': 1,
#  'malcolm': 2,
#  'manhattan': 2,
#  'market': 3,
#  'marks': 4,
#  'mckibbin': 1,
#  'mercer': 3,
#  'midtown': 1,
#  'mott': 4,
#  'moving': 3,
#  'mulberrrry': 1,
#  'mulberry': 3,
#  'murray': 2,
#  'nagle': 1,
#  'nassau': 1,
#  'new': 7,
#  'nicholas': 4,
#  'ninth': 1,
#  'norfolk': 1,
#  'ny': 8,
#  'of': 4,
#  'olive': 1,
#  'one': 1,
#  'orchard': 1,
#  'park': 9,
#  'pearl': 1,
#  'peck': 1,
#  'penn': 2,
#  'piers': 1,
#  'pkwy': 1,
#  'pl': 9,
#  'plz': 4,
#  'prince': 1,
#  'rd': 1,
#  'river': 1,
#  'rivington': 2,
#  'rockefeller': 2,
#  'roosevelt': 1,
#  's': 3,
#  'saint': 7,
#  'second': 1,
#  'sherman': 1,
#  'slip': 1,
#  'smorgasburg': 1,
#  'south': 1,
#  'spring': 3,
#  'sq': 9,
#  'st': 241,
#  'stack': 1,
#  'stanton': 2,
#  'stone': 1,
#  'streer': 1,
#  'suffolk': 1,
#  'suite': 2,
#  'sullivan': 2,
#  'sw': 1,
#  'target!': 3,
#  'terminal': 3,
#  'the': 3,
#  'theater': 1,
#  'theres': 1,
#  'thomas': 1,
#  'thompson': 1,
#  'times': 1,
#  'ues': 1,
#  'union': 5,
#  'university': 2,
#  'vanderbilt': 1,
#  'w': 76,
#  'wall': 2,
#  'washington': 1,
#  'water': 1,
#  'waverly': 1,
#  'west': 14,
#  'william': 1,
#  'x': 2,
#  'york': 10}

# %%
for l in words:
    if not l.isalpha():
        hoi=0
    print(l,words[l])
# Out:
# 800 2
# columbus 4
# ave 158
# 597 1
# 10th 9
# 732 1
# 7th 8
# 111 5
# broadway 33
#  117
# 390 1
# w 76
# 79th 1
# st 241
# 286 1
# 8th 7
# 97th 1
# 231 2
# e 54
# 96th 1
# apt 2
# 6r 1
# 535 1
# malcolm 2
# x 2
# blvd 7
# 275 3
# church 3
# john 2
# stone 1
# 32 1
# gansevoort 1
# 2664 1
# 101 2
# 31st 2
# 248 3
# mckibbin 1
# 137 2
# 33rd 2
# 1240 1
# lexington 14
# 110 5
# 1st 20
# 748 1
# 9th 14
# 2258 2
# 203 3
# 45th 5
# 15 4
# 15th 5
# 38th 3
# 34 3
# 46th 2
# 235 5
# 53rd 3
# 2200 1
# amsterdam 12
# 35 7
# catherine 1
# 76 1
# 47 2
# 21st 3
# central 2
# park 9
# lincoln 1
# center 2
# 103rd 1
# and 5
# 536 1
# 11th 2
# fl 3
# 22 3
# saint 7
# marks 4
# pl 9
# 315 1
# 1231 1
# 162 4
# 2741 1
# new 7
# york 10
# ny 8
# 10039 1
# between 2
# 14th 5
# 177 2
# mulberry 3
# 216 1
# bedford 4
# 125 4
# 10 2
# west 14
# mercer 3
# 108 2
# 39th 5
# 228 1
# canal 1
# 6 1
# 23rd 7
# water 1
# 341 1
# east 10
# 323 1
# greenwich 2
# 330 4
# 6th 3
# 223 1
# 1343 1
# 2nd 17
# exchange 2
# 543 1
# linden 1
# 270 1
# 500 1
# 56th 2
# 280 1
# 1061 1
# 213 2
# 40th 2
# 1593 1
# 69 2
# mott 4
# 36th 5
# 1526 1
# 90 1
# olive 1
# cortlandt 1
# 30th 2
# 456 1
# hudson 4
# 130 1
# 302 1
# 37th 1
# first 3
# maiden 1
# ln 1
# front 2
# 71 1
# irving 1
# 169 1
# 220 1
# 1 7
# penn 2
# plz 4
# 854 1
# 239 1
# 186 1
# franklin 2
# 879 1
# 1490 1
# madison 6
# 1596 1
# 118 1
# essex 2
# 319 1
# 5th 6
# 67 2
# 509 1
# 3rd 14
# 214 2
# 72 2
# floor 3
# 12 2
# thompson 1
# 2235 1
# frederick 3
# douglass 3
# 249 1
# suite 2
# 2e 1
# 467 1
# 134 1
# 27th 1
# 145th 1
# 85th 1
# union 5
# sq 9
# 222 1
# 10011 1
# 487 1
# 277 1
# 29 2
# 405 1
# 58th 3
# 77 2
# pearl 1
# 65 1
# 25 3
# 353 1
# 2730 1
# chez 1
# stack 1
# 1120 1
# of 4
# americas 4
# 264 1
# 64 1
# carmine 1
# 1408 1
# f 1
# kennedy 1
# international 2
# airport 2
# (jfk) 1
# jamaica 1
# 11430 1
# 152 1
# stanton 2
# 3534 1
# 113 3
# 1342 1
# nicholas 4
# 1415 1
# 200 3
# dyckman 2
# 212 2
# 1275 1
# 242 1
# 16th 1
# 400 3
# 20th 4
# 36 1
# 08 1
# 870 3
# doyers 1
# 60 3
# chelsea 1
# piers 1
# 445 1
# 380 1
# 1841 1
# 428 1
# 913 1
# 1731 1
# 209e 1
# 117th 1
# 1650 1
# 161 1
# grand 6
# 398 1
# 23 2
# 79 1
# 94 1
# 764 2
# 148 2
# 75 3
# ckarkson 1
# 62 1
# c 1
# 170 2
# 139 1
# ludlow 2
# 19th 3
# 1016 1
# 1528 1
# 929 1
# 13th 3
# 1442 1
# 1301 1
# the 3
# 191 1
# centre 2
# anywhere 2
# 366 1
# 766 1
# 172 2
# norfolk 1
# 215 2
# 57th 3
# 205 1
# 102 1
# 55 4
# 2479 1
# sw 1
# corner 1
# 1694 1
# 18 2
# murray 2
# south 1
# 210 3
# 34th 2
# b 2
# 449 1
# 206th 1
# 178 1
# greene 1
# 688 1
# 4767 1
# 93 1
# ues 1
# nagle 1
# 93rd 1
# albany 1
# 610 1
# 158 2
# 116th 2
# 42nd 1
# 298 1
# mulberrrry 1
# 416 2
# midtown 1
# manhattan 2
# 425 2
# 201 2
# 112 1
# suffolk 1
# bleecker 6
# 367 1
# terminal 3
# 5 2
# 51 2
# 29th 2
# 59 3
# 4th 2
# 199 2
# 525 1
# 2n 1
# 229 1
# 1059 1
# 503 1
# 342 1
# end 1
# 311 1
# 48th 1
# 20 2
# 875 1
# 30 3
# rockefeller 2
# conc35 1
# 100 3
# 118th 1
# 67th 1
# 49 2
# 44th 2
# 250 3
# houston 2
# 55th 1
# 135 1
# 190 1
# 50th 1
# 265 1
# elizabeth 1
# 1481 1
# river 1
# 181 1
# 3 1
# 601 2
# 26th 2
# 196 1
# 1740 1
# 243 2
# 125th 1
# rivington 2
# streer 1
# 1405 1
# 150 1
# 55b 1
# bayard 1
# 945 2
# 835 1
# 10010 1
# 260 1
# 153 1
# 397 1
# sherman 1
# 6812 1
# bay 1
# pkwy 1
# 80 1
# 505 1
# 2 2
# lafayette 1
# sullivan 2
# 263 1
# 339 1
# 401 2
# 47th 3
# waverly 1
# 120 2
# 39 1
# 241 1
# 312 1
# s 3
# 14 1
# hanover 1
# 421 1
# 80th 2
# 104 1
# 95 1
# 3609 1
# 4973 1
# 226 2
# 49th 2
# market 3
# 132 1
# 86th 1
# university 2
# theres 1
# a 3
# rd 1
# 60th 1
# 174 2
# 2345 1
# 346 1
# 176 1
# 81st 1
# 518 1
# jfk 1
# delta 1
# building 1
# 53 1
# 527 1
# 09 1
# lenox 1
# 245 1
# 63rd 1
# 10065 1
# charlton 1
# 1350 1
# 1830 1
# 2657 1
# nassau 1
# 348 1
# 66th 1
# 547 2
# 1515 1
# 1018 1
# 2048 1
# moving 3
# target! 3
# second 1
# spring 3
# crosby 1
# 2020 1
# 65th 1
# 18th 3
# 85 2
# 68th 3
# thomas 1
# cooper 1
# 440 1
# 508 1
# 117 1
# 1633 1
# 98 1
# henry 1
# 306 1
# william 1
# 455 1
# 1505 1
# 684 1
# 1331 1
# macdougal 1
# 45 2
# peck 1
# slip 1
# 140 1
# 41st 1
# 1260 1
# 26 1
# little 1
# 12th 1
# 4 2
# 974 1
# mad 1
# eats 1
# 326 1
# 61 1
# 74th 1
# 181st 1
# 52nd 1
# 1998 1
# 347 1
# 10016 1
# 131 1
# 1219 1
# 1590 1
# 545 2
# bowery 1
# 128 1
# 2726 1
# 521 2
# 123rd 1
# 591 1
# 27 1
# 2534 1
# 188 1
# orchard 1
# 127 3
# 43rd 2
# 358 1
# 38 1
# 28th 5
# 59th 2
# 1478 1
# one 1
# 141 1
# 69th 1
# ninth 1
# 24 1
# 145 1
# aka 1
# 403 1
# 54th 2
# vanderbilt 1
# 56 1
# 123 1
# 167 1
# 109 2
# 636 1
# 2176 1
# 2133 1
# 499 1
# 2115 1
# 149 1
# 119 1
# 68 1
# 224 2
# prince 1
# 9 2
# 741 1
# 1538 1
# clinton 1
# 420 2
# 918 1
# 2869 1
# 1187 1
# 22nd 1
# 7915 1
# roosevelt 1
# 554 1
# 768 1
# diana 1
# 3009 1
# 701 1
# theater 1
# district 1
# times 1
# 262 1
# 25th 1
# 318 1
# 317 1
# 493 1
# 1690 1
# 1626 1
# 1429 1
# 1827 1
# 694 1
# smorgasburg 1
# at 1
# fulton 2
# cedar 1
# 681 1
# washington 1
# 50 1
# 77th 2
# 78 1
# 333 1
# 680 1
# 51st 1
# 78th 1
# 11 1
# 102nd 1
# 956 1
# 35th 1
# hester 1
# 71st 1
# 801 1
# 862 1
# 1755 1
# francis 1
# lewis 1
# 17 1
# 40 1
# wall 2
# 70 1
# 1550 1
# 274 1
# 233 1
# 560 1
# 1070 1
# 3750 1
